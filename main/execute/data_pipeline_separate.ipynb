# %%
from ml_data_pipeline import MLDataPipeline

# %%
dataPipeline = MLDataPipeline(n_jobs=30)

# %%
##dataPipeline.get_ensemble_tracks()

# %%
dataPipeline.get_ml_features()
# Out:
# IndexError! /work/mflora/SummaryFiles/20170518/2230/ENSEMBLETRACK file at 19 is not available!
# IndexError! /work/mflora/SummaryFiles/20170518/2330/ENSEMBLETRACK file at 19 is not available!
# IndexError! /work/mflora/SummaryFiles/20170518/0230/ENSEMBLETRACK file at 19 is not available!
# IndexError! /work/mflora/SummaryFiles/20170518/0030/ENSEMBLETRACK file at 19 is not available!
# IndexError! /work/mflora/SummaryFiles/20170518/2130/ENSEMBLETRACK file at 19 is not available!
# IndexError! /work/mflora/SummaryFiles/20170518/2030/ENSEMBLETRACK file at 19 is not available!
# IndexError! /work/mflora/SummaryFiles/20170518/0130/ENSEMBLETRACK file at 19 is not available!
# IndexError! /work/mflora/SummaryFiles/20170518/0300/ENSEMBLETRACK file at 36 is not available!
# IndexError! /work/mflora/SummaryFiles/20200521/2300/ENSEMBLETRACK file at 28 is not available!
# IndexError! /work/mflora/SummaryFiles/20170608/0300/ENSEMBLETRACK file at 36 is not available!
# ...
