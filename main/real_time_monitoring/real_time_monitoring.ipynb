# %%
import pandas as pd
import numpy as np
from os.path import join
import joblib
from glob import glob
import sys
sys.path.append('/home/monte.flora/python_packages/master/ml_workflow')
import sys
sys.path.append('/home/monte.flora/python_packages/scikit-explain/')
import skexplain
import shap
#from display_names import to_readable_names, get_units

# %%
#feature_names = X.columns
#display_feature_names = {f : to_readable_names(f) for f in feature_names}
#display_units = {f : get_units(f) for f in feature_names}

#display_feature_names = {**display_feature_names, **FIGURE_MAPPINGS}
#display_units = {**display_units, **UNITS }

# %%
hazard = 'severe_wind'

print(f'Loading data...') 
base_path = '/work/mflora/ML_DATA/DATA'
data_path = join(base_path, f'original_first_hour_training_matched_to_{hazard}_0km_data.feather')
train_df = pd.read_feather(data_path)
# Out:
# Loading data...

# %%
def name_mapping(previous_feature_names):
    """
    The goal of this new method is to convert feature names 
    saved with the ML model into the new feature names.
    """
    corrected_feature_names={}
    for f in previous_feature_names:
        if 'mb' in f and 'temperature' in f:
            new_f = f.replace('mb','')
        elif 'dewpoint' in f and 'mb' in f:
            new_f = f.replace('mb','').replace('dewpoint', 'td')
        elif 'geopotential' in f:
            new_f =f.replace('geopotential_height','geo_hgt').replace('mb', '')
        elif 'cloud_top_temp' in f:
            new_f =f.replace('cloud_top_temp','ctt')
        elif 'divergence' in f:
            new_f =f.replace('divergence_10m','div_10m')
        elif '10-m_bulk_shear' in f:
            new_f =f.replace('10-m_bulk_shear','10-500m_bulkshear')
        elif 'th_e_ml' in f:
            new_f =f.replace('th_e_ml','theta_e')
        elif '1to3km' in f or '3to5km' in f:
            new_f =f.replace('km_max','')
        elif 'bouyancy' in f:
            # Spelling error!
            new_f = f.replace('bouyancy','buoyancy')
        else:
            new_f = f
        
        # Additional '_' in the new format! 
        new_f = new_f.replace('_ens_mean', '__ens_mean')
        new_f = new_f.replace('_ens_std', '__ens_std')
        new_f = new_f.replace('_spatial_mean', '__spatial_mean')
        new_f = new_f.replace('_time_max', '__time_max')
        new_f = new_f.replace('_time_min', '__time_min')
        
        # New naming convention for amplitude stats! 
        new_f = new_f.replace('_ens_std_of_90th', '_amp_ens_std')
        new_f = new_f.replace('_ens_mean_of_90th', '_amp_ens_mean')
        new_f = new_f.replace('_ens_std_of_10th', '_amp_ens_std')
        new_f = new_f.replace('_ens_mean_of_10th', '_amp_ens_mean')
        
        #Baseline var
        #new_f = new_f.replace('uh_probs_>180_prob_max', 'uh_nmep_>180_3km__prob_max')
        #new_f = new_f.replace('hail_probs_>1.0_prob_max', 'hail_nmep_>1.0_3km__prob_max')
        #new_f = new_f.replace('wind_probs_>40_prob_max', 'wnd_nmep_>40_3km__prob_max')
        
        corrected_feature_names[f] = new_f

    return corrected_feature_names

# %%
hazard = 'severe_wind'

base_path = '/work/mflora/ML_DATA/MODEL_SAVES'
model_name = 'LogisticRegression'
model_paths = glob(join(base_path, f'{model_name}_first_hour_{hazard}*'))
model_path = [m for m in model_paths if 'manual' not in m][0]
model_data = joblib.load(model_path)

model = model_data['model']
feature_names = model_data['features']

# %%
path = 'https://storwofstest003.blob.core.windows.net/post/WOFSRun20220404-152140/20220404/2300/'

# wofs_MLDATA_14_20220404_2340_0010.feather
# wofs_MLDATA_15_20220404_2345_0015.feather
# wofs_MLDATA_16_20220404_2350_0020.feather
# wofs_MLDATA_17_20220404_2355_0025.feather
# wofs_MLDATA_18_20220404_0000_0030.feather
df = pd.read_feather(join(path, 'wofs_MLDATA_17_20220404_2355_0025.feather'))

# %%
mapper = name_mapping(feature_names)
names_converted = [mapper.get(f,f) for f in feature_names]

# %%
X = df[names_converted]
pred = model.predict_proba(X)[:,1]
ind = np.argmax(pred)

# %%
np.max(pred)
# Out:
# 0.5276653171390012

# %%
X_train = train_df[feature_names].astype(float)
inds = np.random.choice(len(X_train), size=5000, replace=False)
X_train = X_train.iloc[inds, :]
X_train.reset_index(drop=True, inplace=True)

# %%
explainer = skexplain.ExplainToolkit(('LR', model), X=X.iloc[[ind],:],)

# %%
shap_ds = explainer.local_contributions(method='shap', 
                                        shap_kwargs={'masker' : 
                                          shap.maskers.Partition(X_train, 
                                                                 max_samples=1000, clustering="correlation"), 
                                             'algorithm' : 'permutation'})

# %%
reverse_mapper = {v: k for k, v in mapper.items()}

# %%
sys.path.append('/home/monte.flora/python_packages/wofs_ml_severe/wofs_ml_severe/explain')
from display_names import to_readable_names, get_units

feature_names = X.columns
display_feature_names = {f : to_readable_names(reverse_mapper[f]) for f in feature_names}
display_units = {f : get_units(reverse_mapper[f]) for f in feature_names}

# %%
explainer.plot_contributions(
                           contrib=shap_ds,
                           max_display=25,
                           display_feature_names = display_feature_names,
                            display_units = display_units, 
                                )
# Out:
# (<Figure size 2400x1950 with 3 Axes>, <AxesSubplot:>)

# %%
list(shap_ds.columns)
# Out:
# ['srh_0to1__ens_mean__spatial_mean_contrib',
#  'srh_0to3__ens_mean__spatial_mean_contrib',
#  'cape_ml__ens_mean__spatial_mean_contrib',
#  'cin_ml__ens_mean__spatial_mean_contrib',
#  'shear_u_0to6__ens_mean__spatial_mean_contrib',
#  'shear_v_0to6__ens_mean__spatial_mean_contrib',
#  'shear_u_0to1__ens_mean__spatial_mean_contrib',
#  'shear_v_0to1__ens_mean__spatial_mean_contrib',
#  'lcl_ml__ens_mean__spatial_mean_contrib',
#  'theta_e__ens_mean__spatial_mean_contrib',
#  'u_10__ens_mean__spatial_mean_contrib',
#  'v_10__ens_mean__spatial_mean_contrib',
#  'mid_level_lapse_rate__ens_mean__spatial_mean_contrib',
#  'low_level_lapse_rate__ens_mean__spatial_mean_contrib',
#  'temperature_850__ens_mean__spatial_mean_contrib',
#  'temperature_700__ens_mean__spatial_mean_contrib',
#  'temperature_500__ens_mean__spatial_mean_contrib',
#  'geo_hgt_850__ens_mean__spatial_mean_contrib',
#  'geo_hgt_700__ens_mean__spatial_mean_contrib',
#  'geo_hgt_500__ens_mean__spatial_mean_contrib',
#  'td_850__ens_mean__spatial_mean_contrib',
#  'td_700__ens_mean__spatial_mean_contrib',
#  'td_500__ens_mean__spatial_mean_contrib',
#  'uh_0to2__time_max__ens_mean__spatial_mean_contrib',
#  'uh_2to5__time_max__ens_mean__spatial_mean_contrib',
#  'wz_0to2__time_max__ens_mean__spatial_mean_contrib',
#  'comp_dz__time_max__ens_mean__spatial_mean_contrib',
#  'ws_80__time_max__ens_mean__spatial_mean_contrib',
#  'w_up__time_max__ens_mean__spatial_mean_contrib',
#  'hailcast__time_max__ens_mean__spatial_mean_contrib',
#  'w_1km__time_max__ens_mean__spatial_mean_contrib',
#  '10-500m_bulkshear__time_max__ens_mean__spatial_mean_contrib',
#  'dbz_1to3__time_max__ens_mean__spatial_mean_contrib',
#  'dbz_3to5__time_max__ens_mean__spatial_mean_contrib',
#  'ctt__time_min__ens_mean__spatial_mean_contrib',
#  'buoyancy__time_min__ens_mean__spatial_mean_contrib',
#  'div_10m__time_min__ens_mean__spatial_mean_contrib',
#  'w_down__time_min__ens_mean__spatial_mean_contrib',
#  'srh_0to1__ens_std__spatial_mean_contrib',
#  'srh_0to3__ens_std__spatial_mean_contrib',
#  'cape_ml__ens_std__spatial_mean_contrib',
#  'cin_ml__ens_std__spatial_mean_contrib',
#  'shear_u_0to6__ens_std__spatial_mean_contrib',
#  'shear_v_0to6__ens_std__spatial_mean_contrib',
#  'shear_u_0to1__ens_std__spatial_mean_contrib',
#  'shear_v_0to1__ens_std__spatial_mean_contrib',
#  'lcl_ml__ens_std__spatial_mean_contrib',
#  'theta_e__ens_std__spatial_mean_contrib',
#  'u_10__ens_std__spatial_mean_contrib',
#  'v_10__ens_std__spatial_mean_contrib',
#  'mid_level_lapse_rate__ens_std__spatial_mean_contrib',
#  'low_level_lapse_rate__ens_std__spatial_mean_contrib',
#  'temperature_850__ens_std__spatial_mean_contrib',
#  'temperature_700__ens_std__spatial_mean_contrib',
#  'temperature_500__ens_std__spatial_mean_contrib',
#  'geo_hgt_850__ens_std__spatial_mean_contrib',
#  'geo_hgt_700__ens_std__spatial_mean_contrib',
#  'geo_hgt_500__ens_std__spatial_mean_contrib',
#  'td_850__ens_std__spatial_mean_contrib',
#  'td_700__ens_std__spatial_mean_contrib',
#  'td_500__ens_std__spatial_mean_contrib',
#  'uh_0to2__time_max__ens_std__spatial_mean_contrib',
#  'uh_2to5__time_max__ens_std__spatial_mean_contrib',
#  'wz_0to2__time_max__ens_std__spatial_mean_contrib',
#  'comp_dz__time_max__ens_std__spatial_mean_contrib',
#  'ws_80__time_max__ens_std__spatial_mean_contrib',
#  'w_up__time_max__ens_std__spatial_mean_contrib',
#  'hailcast__time_max__ens_std__spatial_mean_contrib',
#  'w_1km__time_max__ens_std__spatial_mean_contrib',
#  '10-500m_bulkshear__time_max__ens_std__spatial_mean_contrib',
#  'dbz_1to3__time_max__ens_std__spatial_mean_contrib',
#  'dbz_3to5__time_max__ens_std__spatial_mean_contrib',
#  'ctt__time_min__ens_std__spatial_mean_contrib',
#  'buoyancy__time_min__ens_std__spatial_mean_contrib',
#  'div_10m__time_min__ens_std__spatial_mean_contrib',
#  'w_down__time_min__ens_std__spatial_mean_contrib',
#  'uh_0to2__time_max__amp_ens_std_contrib',
#  'uh_0to2__time_max__amp_ens_mean_contrib',
#  'uh_2to5__time_max__amp_ens_std_contrib',
#  'uh_2to5__time_max__amp_ens_mean_contrib',
#  'wz_0to2__time_max__amp_ens_std_contrib',
#  'wz_0to2__time_max__amp_ens_mean_contrib',
#  'comp_dz__time_max__amp_ens_std_contrib',
#  'comp_dz__time_max__amp_ens_mean_contrib',
#  'ws_80__time_max__amp_ens_std_contrib',
#  'ws_80__time_max__amp_ens_mean_contrib',
#  'w_up__time_max__amp_ens_std_contrib',
#  'w_up__time_max__amp_ens_mean_contrib',
#  'hailcast__time_max__amp_ens_std_contrib',
#  'hailcast__time_max__amp_ens_mean_contrib',
#  'w_1km__time_max__amp_ens_std_contrib',
#  'w_1km__time_max__amp_ens_mean_contrib',
#  '10-500m_bulkshear__time_max__amp_ens_std_contrib',
#  '10-500m_bulkshear__time_max__amp_ens_mean_contrib',
#  'dbz_1to3__time_max__amp_ens_std_contrib',
#  'dbz_1to3__time_max__amp_ens_mean_contrib',
#  'dbz_3to5__time_max__amp_ens_std_contrib',
#  'dbz_3to5__time_max__amp_ens_mean_contrib',
#  'ctt__time_min__amp_ens_std_contrib',
#  'ctt__time_min__amp_ens_mean_contrib',
#  'buoyancy__time_min__amp_ens_std_contrib',
#  'buoyancy__time_min__amp_ens_mean_contrib',
#  'div_10m__time_min__amp_ens_std_contrib',
#  'div_10m__time_min__amp_ens_mean_contrib',
#  'w_down__time_min__amp_ens_std_contrib',
#  'w_down__time_min__amp_ens_mean_contrib',
#  'area_contrib',
#  'eccentricity_contrib',
#  'extent_contrib',
#  'major_axis_length_contrib',
#  'minor_axis_length_contrib',
#  'orientation_contrib',
#  'Initialization Time_contrib',
#  'Bias_contrib',
#  'srh_0to1__ens_mean__spatial_mean_val',
#  'srh_0to3__ens_mean__spatial_mean_val',
#  'cape_ml__ens_mean__spatial_mean_val',
#  'cin_ml__ens_mean__spatial_mean_val',
#  'shear_u_0to6__ens_mean__spatial_mean_val',
#  'shear_v_0to6__ens_mean__spatial_mean_val',
#  'shear_u_0to1__ens_mean__spatial_mean_val',
#  'shear_v_0to1__ens_mean__spatial_mean_val',
#  'lcl_ml__ens_mean__spatial_mean_val',
#  'theta_e__ens_mean__spatial_mean_val',
#  'u_10__ens_mean__spatial_mean_val',
#  'v_10__ens_mean__spatial_mean_val',
#  'mid_level_lapse_rate__ens_mean__spatial_mean_val',
#  'low_level_lapse_rate__ens_mean__spatial_mean_val',
#  'temperature_850__ens_mean__spatial_mean_val',
#  'temperature_700__ens_mean__spatial_mean_val',
#  'temperature_500__ens_mean__spatial_mean_val',
#  'geo_hgt_850__ens_mean__spatial_mean_val',
#  'geo_hgt_700__ens_mean__spatial_mean_val',
#  'geo_hgt_500__ens_mean__spatial_mean_val',
#  'td_850__ens_mean__spatial_mean_val',
#  'td_700__ens_mean__spatial_mean_val',
#  'td_500__ens_mean__spatial_mean_val',
#  'uh_0to2__time_max__ens_mean__spatial_mean_val',
#  'uh_2to5__time_max__ens_mean__spatial_mean_val',
#  'wz_0to2__time_max__ens_mean__spatial_mean_val',
#  'comp_dz__time_max__ens_mean__spatial_mean_val',
#  'ws_80__time_max__ens_mean__spatial_mean_val',
#  'w_up__time_max__ens_mean__spatial_mean_val',
#  'hailcast__time_max__ens_mean__spatial_mean_val',
#  'w_1km__time_max__ens_mean__spatial_mean_val',
#  '10-500m_bulkshear__time_max__ens_mean__spatial_mean_val',
#  'dbz_1to3__time_max__ens_mean__spatial_mean_val',
#  'dbz_3to5__time_max__ens_mean__spatial_mean_val',
#  'ctt__time_min__ens_mean__spatial_mean_val',
#  'buoyancy__time_min__ens_mean__spatial_mean_val',
#  'div_10m__time_min__ens_mean__spatial_mean_val',
#  'w_down__time_min__ens_mean__spatial_mean_val',
#  'srh_0to1__ens_std__spatial_mean_val',
#  'srh_0to3__ens_std__spatial_mean_val',
#  'cape_ml__ens_std__spatial_mean_val',
#  'cin_ml__ens_std__spatial_mean_val',
#  'shear_u_0to6__ens_std__spatial_mean_val',
#  'shear_v_0to6__ens_std__spatial_mean_val',
#  'shear_u_0to1__ens_std__spatial_mean_val',
#  'shear_v_0to1__ens_std__spatial_mean_val',
#  'lcl_ml__ens_std__spatial_mean_val',
#  'theta_e__ens_std__spatial_mean_val',
#  'u_10__ens_std__spatial_mean_val',
#  'v_10__ens_std__spatial_mean_val',
#  'mid_level_lapse_rate__ens_std__spatial_mean_val',
#  'low_level_lapse_rate__ens_std__spatial_mean_val',
#  'temperature_850__ens_std__spatial_mean_val',
#  'temperature_700__ens_std__spatial_mean_val',
#  'temperature_500__ens_std__spatial_mean_val',
#  'geo_hgt_850__ens_std__spatial_mean_val',
#  'geo_hgt_700__ens_std__spatial_mean_val',
#  'geo_hgt_500__ens_std__spatial_mean_val',
#  'td_850__ens_std__spatial_mean_val',
#  'td_700__ens_std__spatial_mean_val',
#  'td_500__ens_std__spatial_mean_val',
#  'uh_0to2__time_max__ens_std__spatial_mean_val',
#  'uh_2to5__time_max__ens_std__spatial_mean_val',
#  'wz_0to2__time_max__ens_std__spatial_mean_val',
#  'comp_dz__time_max__ens_std__spatial_mean_val',
#  'ws_80__time_max__ens_std__spatial_mean_val',
#  'w_up__time_max__ens_std__spatial_mean_val',
#  'hailcast__time_max__ens_std__spatial_mean_val',
#  'w_1km__time_max__ens_std__spatial_mean_val',
#  '10-500m_bulkshear__time_max__ens_std__spatial_mean_val',
#  'dbz_1to3__time_max__ens_std__spatial_mean_val',
#  'dbz_3to5__time_max__ens_std__spatial_mean_val',
#  'ctt__time_min__ens_std__spatial_mean_val',
#  'buoyancy__time_min__ens_std__spatial_mean_val',
#  'div_10m__time_min__ens_std__spatial_mean_val',
#  'w_down__time_min__ens_std__spatial_mean_val',
#  'uh_0to2__time_max__amp_ens_std_val',
#  'uh_0to2__time_max__amp_ens_mean_val',
#  'uh_2to5__time_max__amp_ens_std_val',
#  'uh_2to5__time_max__amp_ens_mean_val',
#  'wz_0to2__time_max__amp_ens_std_val',
#  'wz_0to2__time_max__amp_ens_mean_val',
#  'comp_dz__time_max__amp_ens_std_val',
#  'comp_dz__time_max__amp_ens_mean_val',
#  'ws_80__time_max__amp_ens_std_val',
#  'ws_80__time_max__amp_ens_mean_val',
#  'w_up__time_max__amp_ens_std_val',
#  'w_up__time_max__amp_ens_mean_val',
#  'hailcast__time_max__amp_ens_std_val',
#  'hailcast__time_max__amp_ens_mean_val',
#  'w_1km__time_max__amp_ens_std_val',
#  'w_1km__time_max__amp_ens_mean_val',
#  '10-500m_bulkshear__time_max__amp_ens_std_val',
#  '10-500m_bulkshear__time_max__amp_ens_mean_val',
#  'dbz_1to3__time_max__amp_ens_std_val',
#  'dbz_1to3__time_max__amp_ens_mean_val',
#  'dbz_3to5__time_max__amp_ens_std_val',
#  'dbz_3to5__time_max__amp_ens_mean_val',
#  'ctt__time_min__amp_ens_std_val',
#  'ctt__time_min__amp_ens_mean_val',
#  'buoyancy__time_min__amp_ens_std_val',
#  'buoyancy__time_min__amp_ens_mean_val',
#  'div_10m__time_min__amp_ens_std_val',
#  'div_10m__time_min__amp_ens_mean_val',
#  'w_down__time_min__amp_ens_std_val',
#  'w_down__time_min__amp_ens_mean_val',
#  'area_val',
#  'eccentricity_val',
#  'extent_val',
#  'major_axis_length_val',
#  'minor_axis_length_val',
#  'orientation_val',
#  'Initialization Time_val']

# %%
shap_ds['ws_80__time_max__amp_ens_mean_val']
# Out:
# non_performance  LR    38.107845
# Name: ws_80__time_max__amp_ens_mean_val, dtype: float64

# %%
shap_ds['comp_dz__time_max__amp_ens_mean_val']
# Out:
# non_performance  LR    61.567654
# Name: comp_dz__time_max__amp_ens_mean_val, dtype: float64
