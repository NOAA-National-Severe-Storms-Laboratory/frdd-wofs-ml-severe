# %%
import sys
sys.path.append('/home/monte.flora/python_packages/scikit-explain')

from load_models_and_data import load_model_and_data
import itertools 
from os.path import join
from skexplain import ExplainToolkit
import numpy as np

# %%
n_permute = 500
subsample = 1.0
n_jobs=40 

random_state = np.random.RandomState(42)
N = 100000

# %%
path = '/work/mflora/ML_DATA/permutation_importance/'

lead_time = 'first_hour'
opts = ['', 'L1_based']
hazards = ['tornado', 'severe_hail', 'severe_wind']
directions = ['forward', 'backward']

for opt, hazard, direction in itertools.product(opts, hazards, directions):
    print(f'Hazard: {hazard}...Opt: {opt}...Direction: {direction}')
    estimator, X,y = load_model_and_data(hazard, opt)
    explainer = ExplainToolkit(estimator,X,y)
    
    X = X.iloc[inds,:]
    X.reset_index(drop=True, inplace=True)
    y = y[inds]
    
    results_fname = join(path, 'permutation_importance', f'perm_imp_{hazard}_{lead_time}_{opt}_{direction}.nc')
    results = explainer.permutation_importance(n_vars=X.shape[1], 
        evaluation_fn='norm_aupdc', 
        n_permute=n_permute,
        subsample=subsample,
        n_jobs=n_jobs,
        direction=direction,
        verbose=True, 
        return_iterations=False, 
        )

    print(f'Saving {results_fname}...')
    explainer.save(fname=results_fname, data=results)
# Out:
# Hazard: tornado...Opt: ...Direction: forward
# Loading /work/mflora/ML_DATA/MODEL_SAVES/LogisticRegression_first_hour_tornado_under_standard_.pkl...
# Multi-pass iteration 1 out of 113...
#   0%|          | 0/113 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# File ~/miniconda3/envs/wofs_test/lib/python3.8/site-packages/joblib/parallel.py:822, in Parallel.dispatch_one_batch(self, iterator)
#     821 try:
# --> 822     tasks = self._ready_batches.get(block=False)
#     823 except queue.Empty:
#     824     # slice the iterator n_jobs * batchsize items at a time. If the
#     825     # slice returns less than that, then the current batchsize puts
#    (...)
#     828     # accordingly to distribute evenly the last items between all
#     829     # workers.
#
# File ~/miniconda3/envs/wofs_test/lib/python3.8/queue.py:167, in Queue.get(self, block, timeout)
#     166     if not self._qsize():
# --> 167         raise Empty
#     168 elif timeout is None:
#
# Empty:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <module>
#      11 explainer = ExplainToolkit(estimator,X,y)
#      13 results_fname = join(path, 'permutation_importance', f'perm_imp_{hazard}_{lead_time}_{opt}_{direction}.nc')
# ---> 14 results = explainer.permutation_importance(n_vars=X.shape[1],
#      15     evaluation_fn='norm_aupdc',
#      16     n_permute=n_permute,
#      17     subsample=subsample,
#      18     n_jobs=n_jobs,
#      19     direction=direction,
#      20     verbose=True,
#      21     return_iterations=False,
#      22     )
#      24 print(f'Saving {results_fname}...')
#      25 explainer.save(fname=results_fname, data=results)
#
# File ~/python_packages/scikit-explain/skexplain/main/explain_toolkit.py:359, in ExplainToolkit.permutation_importance(self, n_vars, evaluation_fn, direction, subsample, n_jobs, n_permute, scoring_strategy, verbose, return_iterations, random_seed, to_importance)
#     213 def permutation_importance(
#     214     self,
#     215     n_vars,
#    (...)
#     225     to_importance=False,
#     226 ):
#     227     """
#     228     Performs single-pass and/or multi-pass permutation importance using a modified version of the
#     229     PermutationImportance package (skexplain.PermutationImportance) [1]_. The single-pass approach was first
#    (...)
#     357             evaluation_fn:     norm_aupdc
#     358     """
# --> 359     results_ds, scoring_strategy = self.global_obj.calc_permutation_importance(
#     360         n_vars=n_vars,
#     361         evaluation_fn=evaluation_fn,
#     362         subsample=subsample,
#     363         n_jobs=n_jobs,
#     364         n_permute=n_permute,
#     365         scoring_strategy=scoring_strategy,
#     366         verbose=verbose,
#     367         direction=direction,
#     368         return_iterations=return_iterations,
#     369         random_seed=random_seed,
#     370     )
#     372     self.attrs_dict["n_multipass_vars"] = n_vars
#     373     self.attrs_dict["method"] = "permutation_importance"
#
# File ~/python_packages/scikit-explain/skexplain/main/global_explainer.py:233, in GlobalExplainer.calc_permutation_importance(self, n_vars, evaluation_fn, subsample, n_jobs, n_permute, scoring_strategy, direction, verbose, return_iterations, random_seed)
#     231 # loop over each estimator
#     232 for estimator_name, estimator in self.estimators.items():
# --> 233     pi_result = sklearn_permutation_importance(
#     234         model=estimator,
#     235         scoring_data=(self.X.values, y.values),
#     236         evaluation_fn=evaluation_fn,
#     237         variable_names=self.feature_names,
#     238         scoring_strategy=scoring_strategy,
#     239         subsample=subsample,
#     240         nimportant_vars=n_vars,
#     241         njobs=n_jobs,
#     242         n_permute=n_permute,
#     243         verbose=verbose,
#     244         direction=direction,
#     245         random_seed=random_seed,
#     246     )
#     247     if direction == 'forward':
#     248         scores = all_permuted_score(estimator,
#     249                                     self.X.values,
#     250                                     y.values,
#     251                                     evaluation_fn=evaluation_fn,
#     252                                     n_permute=n_permute,
#     253                                     subsample=subsample, random_seed=random_seed)
#
# File ~/python_packages/scikit-explain/skexplain/main/PermutationImportance/permutation_importance.py:167, in sklearn_permutation_importance(model, scoring_data, evaluation_fn, scoring_strategy, variable_names, nimportant_vars, direction, njobs, n_permute, subsample, verbose, random_seed, **scorer_kwargs)
#     156 else:
#     157     scoring_fn = score_trained_sklearn_model(
#     158         model,
#     159         evaluation_fn,
#    (...)
#     164         scorer_kwargs={},
#     165     )
# --> 167 return permutation_importance(
#     168     scoring_data=scoring_data,
#     169     scoring_fn=scoring_fn,
#     170     scoring_strategy=scoring_strategy,
#     171     variable_names=variable_names,
#     172     nimportant_vars=nimportant_vars,
#     173     njobs=njobs,
#     174     verbose=verbose,
#     175     direction=direction,
#     176     random_seed=random_seed,
#     177     scorer_kwargs={},
#     178 )
#
# File ~/python_packages/scikit-explain/skexplain/main/PermutationImportance/permutation_importance.py:81, in permutation_importance(scoring_data, scoring_fn, scoring_strategy, variable_names, nimportant_vars, njobs, direction, verbose, random_seed, **kwargs)
#      79     raise ValueError("Must declare scoring data!")
#      80 else:
# ---> 81     return abstract_variable_importance(
#      82         training_data=(np.array([]), np.array([])),
#      83         scoring_data=scoring_data,
#      84         scoring_fn=scoring_fn,
#      85         scoring_strategy=scoring_strategy,
#      86         selection_strategy=selection_strategy,
#      87         variable_names=variable_names,
#      88         nimportant_vars=nimportant_vars,
#      89         njobs=njobs,
#      90         verbose=verbose,
#      91         random_seed=random_seed,
#      92         direction=direction,
#      93     )
#
# File ~/python_packages/scikit-explain/skexplain/main/PermutationImportance/abstract_runner.py:121, in abstract_variable_importance(training_data, scoring_data, scoring_fn, scoring_strategy, selection_strategy, variable_names, nimportant_vars, method, perm_method, njobs, verbose, random_seed, **kwargs)
#     119     result = _singlethread_iteration(selection_iter, scoring_fn)
#     120 else:
# --> 121     result = _multithread_iteration(selection_iter, scoring_fn, njobs, nimportant_vars-i)
#     123 next_result = add_ranks_to_dict(result, variable_names, scoring_strategy)
#     124 best_var = min(next_result.keys(), key=lambda key: next_result[key][0])
#
# File ~/python_packages/scikit-explain/skexplain/main/PermutationImportance/abstract_runner.py:177, in _multithread_iteration(selection_iterator, scoring_fn, njobs, total)
#     173     result[var] = score
#     175     return result
# --> 177 result = run_parallel(func=worker,
#     178             args_iterator=selection_iterator,
#     179             kwargs={},
#     180             nprocs_to_use=njobs,
#     181             total=total,
#     182                      )
#     183 return merge_dict(result)
#
# File ~/python_packages/scikit-explain/skexplain/common/multiprocessing_utils.py:128, in run_parallel(func, args_iterator, kwargs, nprocs_to_use, total)
#     121     raise ValueError(
#     122         f"User requested {nprocs_to_use} processors, but system only has {mp.cpu_count()}!"
#     123     )
#     125 aprun = ParallelExecutor(n_jobs=nprocs_to_use, require="sharedmem")(
#     126     bar="tqdm", total=total
#     127 )
# --> 128 results = aprun(
#     129     delayed(LogExceptions(func))(*args, **kwargs) for args in args_iterator
#     130 )
#     132 return results
#
# File ~/python_packages/scikit-explain/skexplain/common/multiprocessing_utils.py:53, in ParallelExecutor.<locals>.aprun.<locals>.tmp(op_iter)
#      51 else:
#      52     raise ValueError("Value %s not supported as bar type" % bar)
# ---> 53 return Parallel(**joblib_args)(bar_func(op_iter))
#
# File ~/miniconda3/envs/wofs_test/lib/python3.8/site-packages/joblib/parallel.py:1046, in Parallel.__call__(self, iterable)
#    1043 if self.dispatch_one_batch(iterator):
#    1044     self._iterating = self._original_iterator is not None
# -> 1046 while self.dispatch_one_batch(iterator):
#    1047     pass
#    1049 if pre_dispatch == "all" or n_jobs == 1:
#    1050     # The iterable was consumed all at once by the above for loop.
#    1051     # No need to wait for async callbacks to trigger to
#    1052     # consumption.
#
# File ~/miniconda3/envs/wofs_test/lib/python3.8/site-packages/joblib/parallel.py:833, in Parallel.dispatch_one_batch(self, iterator)
#     830 n_jobs = self._cached_effective_n_jobs
#     831 big_batch_size = batch_size * n_jobs
# --> 833 islice = list(itertools.islice(iterator, big_batch_size))
#     834 if len(islice) == 0:
#     835     return False
#
# File ~/miniconda3/envs/wofs_test/lib/python3.8/site-packages/tqdm/notebook.py:257, in tqdm_notebook.__iter__(self)
#     255 def __iter__(self):
#     256     try:
# --> 257         for obj in super(tqdm_notebook, self).__iter__():
#     258             # return super(tqdm...) will not catch exception
#     259             yield obj
#     260     # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#
# File ~/miniconda3/envs/wofs_test/lib/python3.8/site-packages/tqdm/std.py:1180, in tqdm.__iter__(self)
#    1177 time = self._time
#    1179 try:
# -> 1180     for obj in iterable:
#    1181         yield obj
#    1182         # Update and possibly print the progressbar.
#    1183         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/python_packages/scikit-explain/skexplain/common/multiprocessing_utils.py:128, in <genexpr>(.0)
#     121     raise ValueError(
#     122         f"User requested {nprocs_to_use} processors, but system only has {mp.cpu_count()}!"
#     123     )
#     125 aprun = ParallelExecutor(n_jobs=nprocs_to_use, require="sharedmem")(
#     126     bar="tqdm", total=total
#     127 )
# --> 128 results = aprun(
#     129     delayed(LogExceptions(func))(*args, **kwargs) for args in args_iterator
#     130 )
#     132 return results
#
# File ~/python_packages/scikit-explain/skexplain/main/PermutationImportance/selection_strategies.py:65, in SelectionStrategy.generate_all_datasets(self)
#      63 for var in range(self.num_vars):
#      64     if var not in self.important_vars:
# ---> 65         training_data, scoring_data = self.generate_datasets(
#      66             self.important_vars
#      67             + [var,]
#      68         )
#      69         yield (training_data, scoring_data, var)
#
# File ~/python_packages/scikit-explain/skexplain/main/PermutationImportance/selection_strategies.py:321, in ForwardPermutationImportanceSelectionStrategy.generate_datasets(self, important_variables)
#     319 scoring_inputs, scoring_outputs = self.scoring_data
#     320 # If a feature has been deemed important it remains shuffled
# --> 321 complete_scoring_inputs = make_data_from_columns(
#     322     [
#     323         get_data_subset(
#     324             scoring_inputs
#     325             if i in important_variables
#     326             else self.shuffled_scoring_inputs,
#     327             columns = [i],
#     328         )
#     329         for i in range(self.num_vars)
#     330     ],
#     331     index=self.original_index,
#     332 )
#     334 return self.training_data, (complete_scoring_inputs, scoring_outputs)
#
# File ~/python_packages/scikit-explain/skexplain/main/PermutationImportance/utils.py:87, in make_data_from_columns(columns_list, index)
#      85         return df
#      86 elif isinstance(columns_list[0], np.ndarray):
# ---> 87     return np.column_stack(columns_list)
#      88 else:
#      89     raise InvalidDataException(
#      90         columns_list,
#      91         "Columns_list must come from a pandas dataframe or numpy arrays",
#      92     )
#
# File <__array_function__ internals>:5, in column_stack(*args, **kwargs)
#
# File ~/miniconda3/envs/wofs_test/lib/python3.8/site-packages/numpy/lib/shape_base.py:656, in column_stack(tup)
#     654         arr = array(arr, copy=False, subok=True, ndmin=2).T
#     655     arrays.append(arr)
# --> 656 return _nx.concatenate(arrays, 1)
#
# File <__array_function__ internals>:5, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:
